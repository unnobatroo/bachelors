# %% [markdown]
# # Week 4 Practice: Solution Explanations
#
# This notebook combines list/tuple processing tasks.
#
# For each task, explanations focus on:
# - the core Python construct used
# - why that construct matches the problem
# - edge-case handling

# %% [markdown]
# ## Task 1: Highest Score in a List of Tuples
#
# Approach:
# - Use `max(..., key=...)` to compare only by score.
# - Keep name and score together to preserve context.
#
# Why it works:
# - `max` applies the key function consistently and returns the full tuple with best score.

# %%
from itertools import groupby
from math import isqrt


def print_highest_score(students):
    """Prints a student with the highest score"""
    result = max(students, key=lambda student: student[1])
    print(f"Highest score: {result[0]} with {result[1]} points")


print_highest_score([("Anna", 80), ("Bob", 92), ("Eva", 88), ("Jaloliddin", -83)])
# Out:
# Highest score: Bob with 92 points

# %% [markdown]
# ## Task 2: Run-Length Encoding (RLE)
#
# Approach:
# - Group consecutive equal values with `itertools.groupby`.
# - Convert each group into `(value, count)`.
#
# Why it works:
# - RLE is defined exactly by maximal consecutive groups.

# %%
def print_rle(values):
    """Compresses data by replacing consecutive repeated values
    with a value-count pair"""
    encoded = [(value, len(list(group))) for value, group in groupby(values)]
    print(f"RLE: {encoded}")


print_rle([1, 1, 1, 2, 3, 3, 3, 3, 4, 4, 4, 1, 1])
# Out:
# RLE: [(1, 3), (2, 1), (3, 4), (4, 3), (1, 2)]

# %% [markdown]
# ## Task 3: Middle Value in 101 Elements
#
# Approach:
# - Validate list size first.
# - Sort and take index 50 (0-based) as the middle element.
# - Count elements smaller and greater than that value.
#
# Why it works:
# - In a sorted list of 101 elements, index 50 splits the list into 50 on each side.

# %%
def print_101(values):
    """Finds the middle element in a list - the one with equal
    numbers of greater and smaller elements"""
    if len(values) != 101:
        print("List must have exactly 101 elements")
        return

    sorted_values = sorted(values)

    middle = sorted_values[50]
    print(f"Middle: {middle}")

    smaller_count = sum(1 for value in values if value < middle)
    print(f"Smaller count: {smaller_count}")

    greater_count = sum(1 for value in values if value > middle)
    print(f"Greater count: {greater_count}")


print_101(list(range(1, 102)))
# Out:
# Middle: 51
# Smaller count: 50
# Greater count: 50

# %% [markdown]
# ## Task 4: Weighted Sum of Two Lists
#
# Approach:
# - Pair values with `zip` and sum products.
#
# Why it works:
# - This computes the dot product directly: $\sum_i a_i b_i$.

# %%
def print_weighted(lst1, lst2):
    """Calculates weighted sum"""
    result = sum(value1 * value2 for value1, value2 in zip(lst1, lst2))
    print(f"Weighted sum: {result}")


print_weighted(list(range(1, 10)), list(range(10, 20)))
# Out:
# Weighted sum: 690

# %% [markdown]
# ## Task 5: Amicable Pairs in a List
#
# Approach:
# - Build a helper for proper-divisor sums.
# - Precompute sums in a dictionary for reuse.
# - Check two-way condition and deduplicate pairs with sorted tuples.
#
# Why it works:
# - A pair $(a, b)$ is amicable iff each maps to the other under proper-divisor sum.

# %%
def proper_divisor_sum(n):
    """Helper function for print_amicable_pair()"""
    if n < 2:
        return 0

    total = 1

    for divisor in range(2, isqrt(n) + 1):
        if n % divisor == 0:
            total += divisor
            pair_divisor = n // divisor
            if pair_divisor != divisor:
                total += pair_divisor

    return total


def print_amicable_pair(values):
    """Determines whether a given integer list contains two amicable numbers.
    Two numbers are amicable if the sum of their proper divisors equals the other"""

    values = [num for num in dict.fromkeys(values) if num > 1]
    sums = {num: proper_divisor_sum(num) for num in values}
    values_set = set(values)

    pairs = []
    seen = set()

    for a in values:
        b = sums[a]
        if b != a and b in values_set and sums[b] == a:
            pair = tuple(sorted([a, b]))
            if pair not in seen:
                pairs.append(pair)
                seen.add(pair)

    if pairs:
        print(f"Amicable pairs: {pairs}")
    else:
        print("No amicable pairs found")


print_amicable_pair([10, 220, 5, 284, 12])
print_highest_score([("Anna", 80), ("Bob", 92), ("Eva", 88), ("Jaloliddin", -83)])
# Out:
# Amicable pairs: [(220, 284)]
# Highest score: Bob with 92 points
