# %%
def func_a():
    return 1
    print("Hi!")
    
   
print(func_a()) # 1

# %%
# As soon as return 1 executes → function exits immediately
# print("Hi!") is never executed

# %%
def func_a():
    try: 
        return 1 
    except: 
        return 2 
    finally: 
        return 3
    
    
print(func_a()) #

# %%
# try block runs → return 1 is encountered
# BUT before returning → Python executes finally
# finally contains return 3 → this overrides the previous return

# %%
def func_a():
    try: 
        return 1 
    except: 
        return 2 
    finally: 
        print("Done")
    
    
print(func_a())

# %%
def fun(a):
    if a > 29:
        return 3
    else:
        return a + fun(a + 3)  
# 25 + fun(25+3)
# 28 + fun(28+3)
    
print(fun(25)) # 56

# %%
# Don't run 
def factorial(n):
    return n * factorial(n - 1)


print(factorial(4))

# %%
var = 2


def mult_by_var(x):
    return x * var


print(mult_by_var(7))

# %%
var = 2


def mult_by_var(x=10):
    return x * var


print(mult_by_var())

# %%
def mult(x):
    var = 7
    return x * var


var = 3
print(mult(7))

# %%
def adding(x):
    var1 = 7
    return x + var1

print(adding(4))    # 
print(var1)     #

# %%
var = 2

def mult_by_var(x=10):
    return x * var


print(mult_by_var(7))

# %%
def g(y):
    global x
    print(x)  # 5
    print(x+1) # 6
    x = x+1 
    
x = 5
g(x)
print(x) # 6

# %%
def outer_func():
    a = 10
    print(x)   # 30
    print("outer: a", a) # 10 
    def inner_func():
        b = 20
        print("inside inner_func(): a", a) # 10
        print(x)  # 30
    inner_func() 
    print(b)  # error
        
x = 30    
        
outer_func()

# %%
def func(event, log = []):
    print(id(log))
    log.append(event)
    print(id(log))
    return log 


print(func("User logged.")) # 
print(func("User logout.")) #

# %%
def func(event, log = " "):
    print(id(log))
    log = log + event
    print(id(log))
    return log 


print(func("User logged.")) # 
print(func("User logout.")) #

# %%
def func(event, log = []):
    log.append(event)
    return log 


print(func("User logged.", []))
print(func("User logout.", []))

# %%
Default arguments are initialized once when the function is defined

# %%
def func(event, log):
    log.append(event)
    return log 

log = []
print(func("User logged.", log))
print(func("User logout.", log))

# %%
def func(event):
    log = []
    log.append(event)
    return log 


print(func("User logged."))
print(func("User logout."))

# %%
def func(event, log = " "):
    log = log + event
    return log 


print(func("User logged.")) # 
print(func("User logout.")) #
